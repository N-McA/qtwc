# %%
import skimage
import skimage.util
import skimage.io

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = skimage.io.imread('imgs/quad-arm-up.jpg')
plt.imshow(img)

# %%
padded_img = skimage.util.pad(img, pad_width=[(100, 0), (0, 0), (0, 0)], mode='edge')
plt.imshow(img)
